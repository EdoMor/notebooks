# %%
import matplotlib.pyplot as plt
import numpy as np
from sympy import *
import ease_of_live_scripts as es

# %%
X=np.linspace(-0.07,0.07,1000)
Pi=np.pi

# %%
z=0.82
k=(2*np.pi)/(632.8*(10**(-9)))
d=0.16*10**(-3)
A=20
data=es.read('exp1125/original parameters/single slit/0.04','sweep 2.txt')
plt.plot(data['angle'],-data['power'])
# plt.plot(X,es.single_slit_model(X,A,z,d,k))
plt.legend(['data','theory'])
plt.show()

# %%
z=1
k=1
d=1
L=1

data=np.genfromtxt('data2.csv', delimiter=',')
plt.figure()
plt.plot(X,data)
plt.plot(X,I(X))
plt.legend(['data','expected'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-9c6dd9379e6a> in <module>
#       5 def I(x):
#       6     return (8*z*np.cos((k*L*x)/(2*z))**2*np.sin((d*k*x)/(2*z))**2)/(k*Pi*x**2)
# ----> 7 data=np.genfromtxt('data2.csv', delimiter=',')
#       8 plt.figure()
#       9 plt.plot(X,data)
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    1747             fname = os_fspath(fname)
#    1748         if isinstance(fname, str):
# -> 1749             fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
# ...

# %%
z=1
k=1
d=1
L=1
n=1

data=np.genfromtxt('datan.csv', delimiter=',')
plt.figure()
plt.plot(X,data)
plt.plot(X,I(X))
plt.legend(['data','expected'])
plt.show()
